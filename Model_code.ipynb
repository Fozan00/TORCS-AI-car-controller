# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Input, concatenate
from keras.layers.core import Dense, Dropout, Activation
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder


def read_data(filename):
    file = open(filename, "r")
    main_list = []
    str = file.readline()
    while str:
        list1 = []
        index1 = str.find('angle', 0)
        index2 = str.find(']', index1)
        angle = ''
        for i in range(index1 + 8, index2):
            angle += str[i]
        list1.append(float(angle))
        ########################################
        index1 = str.find('curLapTime', index2)
        index2 = str.find(']', index1)
        curLapTime = ''
        for i in range(index1 + 13, index2):
            curLapTime += str[i]
        list1.append(float(curLapTime))
        ########################################
        index1 = str.find('damage', index2)
        index2 = str.find(']', index1)
        damage = ''
        for i in range(index1 + 9, index2):
            damage += str[i]
        list1.append(float(damage))
        ########################################
        index1 = str.find('distFromStart', index2)
        index2 = str.find(']', index1)
        distFromStart = ''
        for i in range(index1 + 16, index2):
            distFromStart += str[i]
        list1.append(float(distFromStart))
        ########################################
        index1 = str.find('distRaced', index2)
        index2 = str.find(']', index1)
        distRaced = ''
        for i in range(index1 + 12, index2):
            distRaced += str[i]
        list1.append(float(distRaced))
        #######################################
        index1 = str.find('fuel', index2)
        index2 = str.find(']', index1)
        fuel = ''
        for i in range(index1 + 7, index2):
            fuel += str[i]
        list1.append(float(fuel))
        ########################################
        index1 = str.find('gear', index2)
        index2 = str.find(']', index1)
        gear = ''
        for i in range(index1 + 7, index2):
            gear += str[i]
        list1.append(float(gear))
        ########################################
        index1 = str.find('lastLapTime', index2)
        index2 = str.find(']', index1)
        lastLapTime = ''
        for i in range(index1 + 14, index2):
            lastLapTime += str[i]
        list1.append(float(lastLapTime))
        ########################################
        index1 = str.find('racePos', index2)
        index2 = str.find(']', index1)
        racePos = ''
        for i in range(index1 + 10, index2):
            racePos += str[i]
        list1.append(float(racePos))
        ########################################

        index1 = str.find('rpm', index2)
        index2 = str.find(']', index1)
        rpm = ''
        for i in range(index1 + 6, index2):
            rpm += str[i]
        list1.append(float(rpm))
        ########################################
        index1 = str.find('speedX', index2)
        index2 = str.find(']', index1)
        speedX = ''
        for i in range(index1 + 9, index2):
            speedX += str[i]
        list1.append(float(speedX))
        ########################################
        index1 = str.find('speedY', index2)
        index2 = str.find(']', index1)
        speedY = ''
        for i in range(index1 + 9, index2):
            speedY += str[i]
        list1.append(float(speedY))
        ########################################
        index1 = str.find('speedZ', index2)
        index2 = str.find(']', index1)
        speedZ = ''
        for i in range(index1 + 9, index2):
            speedZ += str[i]
        list1.append(float(speedZ))
        ########################################
        index1 = str.find('track', index2)
        index2 = str.find(',', index1)
        track0 = ''
        for i in range(index1 + 8, index2):
            track0 += str[i]
        list1.append(float(track0))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track1 = ''
        for i in range(index1, index2):
            track1 += str[i]
        list1.append(float(track1))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track2 = ''
        for i in range(index1, index2):
            track2 += str[i]
        list1.append(float(track2))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track3 = ''
        for i in range(index1, index2):
            track3 += str[i]
        list1.append(float(track3))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track4 = ''
        for i in range(index1, index2):
            track4 += str[i]
        list1.append(float(track4))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track5 = ''
        for i in range(index1, index2):
            track5 += str[i]
        list1.append(float(track5))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track6 = ''
        for i in range(index1, index2):
            track6 += str[i]
        list1.append(float(track6))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track7 = ''
        for i in range(index1, index2):
            track7 += str[i]
        list1.append(float(track7))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track8 = ''
        for i in range(index1, index2):
            track8 += str[i]
        list1.append(float(track8))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track9 = ''
        for i in range(index1, index2):
            track9 += str[i]
        list1.append(float(track9))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track10 = ''
        for i in range(index1, index2):
            track10 += str[i]
        list1.append(float(track10))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track11 = ''
        for i in range(index1, index2):
            track11 += str[i]
        list1.append(float(track11))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track12 = ''
        for i in range(index1, index2):
            track12 += str[i]
        list1.append(float(track12))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track13 = ''
        for i in range(index1, index2):
            track13 += str[i]
        list1.append(float(track13))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track14 = ''
        for i in range(index1, index2):
            track14 += str[i]
        list1.append(float(track14))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track15 = ''
        for i in range(index1, index2):
            track15 += str[i]
        list1.append(float(track15))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track16 = ''
        for i in range(index1, index2):
            track16 += str[i]
        list1.append(float(track16))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        track17 = ''
        for i in range(index1, index2):
            track17 += str[i]
        list1.append(float(track17))
        ########################################
        index1 = index2 + 2
        index2 = str.find(']', index1)
        track18 = ''
        for i in range(index1, index2):
            track18 += str[i]
        list1.append(float(track18))
        ########################################
        index1 = str.find('trackPos', index2)
        index2 = str.find(']', index1)
        trackPos = ''
        for i in range(index1 + 11, index2):
            trackPos += str[i]
        list1.append(float(trackPos))
        ########################################
        index1 = str.find('wheelSpinVel', index2)
        index2 = str.find(',', index1)
        wheelSpinVel0 = ''
        for i in range(index1 + 15, index2):
            wheelSpinVel0 += str[i]

        list1.append(float(wheelSpinVel0))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        wheelSpinVel1 = ''
        for i in range(index1, index2):
            wheelSpinVel1 += str[i]
        list1.append(float(wheelSpinVel1))
        ########################################
        index1 = index2 + 2
        index2 = str.find(',', index1)
        wheelSpinVel2 = ''
        for i in range(index1, index2):
            wheelSpinVel2 += str[i]
        list1.append(float(wheelSpinVel2))
        ########################################
        index1 = index2 + 2
        index2 = str.find(']', index1)
        wheelSpinVel3 = ''
        for i in range(index1, index2):
            wheelSpinVel3 += str[i]
        list1.append(float(wheelSpinVel3))
        ########################################

        index1 = str.find('accel', index2)
        index2 = str.find(')', index1)
        accel = ''
        for i in range(index1 + 6, index2):
            accel += str[i]
        list1.append(float(accel))
        ##########################################
        index1 = str.find('brake', index2)
        index2 = str.find(')', index1)
        brake = ''
        for i in range(index1 + 6, index2):
            brake += str[i]
        list1.append(float(brake))
        ##########################################
        index1 = str.find('steer', index2)
        index2 = str.find(')', index1)
        steer = ''
        for i in range(index1 + 6, index2):
            steer += str[i]
        list1.append(float(steer))

        main_list.append(list1)
        str = file.readline()
    file.close()
    return main_list


def get_dataframe(filename):
    main_list = read_data(filename)
    df = pd.DataFrame(main_list, columns=['angle', 'curLapTime', 'damage', 'distFromStart', 'distRaced', 'fuel', 'gear',
                                          'lastLapTime', 'racePos', 'rpm', 'speedX', 'speedY', 'speedZ', 'track0',
                                          'track1', 'track2', 'track3', 'track4', 'track5', 'track6', 'track7',
                                          'track8',
                                          'track9', 'track10', 'track11', 'track12', 'track13', 'track14', 'track15',
                                          'track16', 'track17', 'track18', 'trackPos', 'wheelSpinVel0', 'wheelSpinVel1',
                                          'wheelSpinVel2', 'wheelSpinVel3', 'accel', 'brake', 'steer'])
    return df

df = get_dataframe("cg_track_3.txt")
df = pd.concat([df, get_dataframe("cg_track_1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("cg_track_2.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("dirt 1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("dirt 3a.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("dirt 3b.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("dirt 4.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("dirt 5.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("street 1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("Crock.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("E-track.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("Oval C.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("Oval E- 1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("Oval E.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("oval_track_A_speedway.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("oval_track_B_speedway.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("oval_track_D_speedway.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("oval_track_F_speedway.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("oval_track_G_speedway.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("Wheel 1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("new_A-speedway.txt")], ignore_index=True, axis=0)

# df = pd.concat([df, get_dataframe("new_Dirt1.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("new_E-track4.txt")], ignore_index=True, axis=0)
# df = pd.concat([df, get_dataframe("new_aalborg.txt")], ignore_index=True, axis=0)
# df = pd.concat([df, get_dataframe("new_brondehatch.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("new_cg_track_1.txt")], ignore_index=True, axis=0)
# df = pd.concat([df, get_dataframe("new_dirt3.txt")], ignore_index=True, axis=0)
# df = pd.concat([df, get_dataframe("new_dirt4.txt")], ignore_index=True, axis=0)
# df = pd.concat([df, get_dataframe("new_dirt5.txt")], ignore_index=True, axis=0)
df = pd.concat([df, get_dataframe("new_spring.txt")], ignore_index=True, axis=0)

# %%
print(len(df))
new_df = pd.DataFrame(columns=['angle', 'curLapTime', 'damage', 'distFromStart', 'distRaced', 'fuel', 'gear',
                                          'lastLapTime', 'racePos', 'rpm', 'speedX', 'speedY', 'speedZ', 'track0',
                                          'track1', 'track2', 'track3', 'track4', 'track5', 'track6', 'track7',
                                          'track8',
                                          'track9', 'track10', 'track11', 'track12', 'track13', 'track14', 'track15',
                                          'track16', 'track17', 'track18', 'trackPos', 'wheelSpinVel0', 'wheelSpinVel1',
                                          'wheelSpinVel2', 'wheelSpinVel3', 'accel', 'brake', 'steer'])
length = len(df)
index_start = 0
gap_val = 15
while index_start + gap_val < length:
    tmp = df.iloc[index_start:index_start+gap_val]
    arr = np.array(tmp.mean())
    new_df.loc[len(new_df)] = arr
    index_start = index_start + gap_val

print(len(new_df))

X = new_df.values[:, 0:37]
X_steer = X.copy()
Y_steer = new_df.values[:, 37:40]
# Out:
# 86710
# 5780

# %%
start_layer = Input(shape=(37,))
first = Dense(37, kernel_initializer='normal', activation='linear')(start_layer)
second = Dropout(0.2)(first)
third = Dense(37, kernel_initializer='normal', activation='linear')(start_layer)
fourth = Dropout(0.2)(third)
fifth = Dense(37, kernel_initializer='normal', activation='linear')(start_layer)
sixth = Dropout(0.2)(fifth)
merge = concatenate([second, fourth, sixth])
shayad_last = Dense(3, kernel_initializer='normal', activation='linear')(merge)
model = Model(inputs=start_layer, outputs=shayad_last)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])


model.fit(X_steer, Y_steer, epochs=150, batch_size=32, verbose=1)

val = [0.00128341, 17.728, 0, 387.834, 412.834, 93.8113, 3, 0, 2, 5464.95, 101.099, -0.186579, 11.6411,
       5.72672, 5.94533, 6.69407, 8.40451, 12.9769, 84.6973, 99.3661, 47.8621, 37.021, 28.0558, 21.269,
       16.4649, 13.1529, 10.8525, 8.02093, 5.90623, 4.8945, 4.41547, 4.27329,
       -0.145341, 85.5445, 84.2827, 87.0733, 86.4096]   # 900


var = model.predict([val])
print(var)
val = [4.35233e-03, 3.51860e+01, 0.00000e+00, 8.68056e+02, 8.93056e+02, 9.36739e+01,
       3.00000e+00, 0.00000e+00, 3.00000e+00, 5.43349e+03, 1.01086e+02, 8.37913e-01,
       2.24550e+00, 3.62479e+00, 3.74789e+00, 4.15008e+00, 4.98653e+00, 6.68568e+00,
       8.84945e+00, 1.05135e+01, 1.27767e+01, 1.58371e+01, 1.98612e+01, 2.48914e+01,
       3.08012e+01, 3.73492e+01, 4.42721e+01, 1.84371e+01, 9.71280e+00, 7.52171e+00,
       6.62521e+00, 6.37531e+00, 2.75048e-01, 8.36499e+01, 8.60588e+01, 8.52427e+01,
       8.72489e+01]   # 1707
var = model.predict([val])
print(var)
val = [-4.17407e-02,  9.27620e+01,  1.80000e+01,  2.45172e+03,  2.47672e+03,
  9.32545e+01,  3.00000e+00,  0.00000e+00,  4.00000e+00,  5.59819e+03,
  9.96608e+01, -5.20594e+00, -5.04906e-01,  6.65324e+00,  6.83171e+00,
  7.62919e+00,  9.54891e+00,  1.52681e+01,  9.40341e+01,  5.45965e+01,
  3.86720e+01,  3.00119e+01,  2.33401e+01,  1.79923e+01,  1.40031e+01,
  1.11555e+01,  9.14432e+00,  6.65698e+00,  4.81067e+00,  3.93073e+00,
  3.50505e+00,  3.35603e+00, -3.29349e-01,  8.52044e+01,  8.15954e+01,
  8.88491e+01,  8.88782e+01]
var = model.predict([val])
print(var)
import os.path
if os.path.isfile('./new_model.h5') is False:
    model.save('./new_model.h5')
# Out:
# Epoch 1/150
# 181/181 [==============================] - 1s 4ms/step - loss: 3209.7920 - accuracy: 0.3592
# Epoch 2/150
# 181/181 [==============================] - 1s 4ms/step - loss: 386.3678 - accuracy: 0.3865
# Epoch 3/150
# 181/181 [==============================] - 1s 4ms/step - loss: 146.8001 - accuracy: 0.4022
# Epoch 4/150
# 181/181 [==============================] - 1s 4ms/step - loss: 74.8749 - accuracy: 0.4182
# Epoch 5/150
# 181/181 [==============================] - 1s 4ms/step - loss: 49.9581 - accuracy: 0.4118
# Epoch 6/150
# 181/181 [==============================] - 1s 4ms/step - loss: 30.9184 - accuracy: 0.4171
# Epoch 7/150
# 181/181 [==============================] - 1s 4ms/step - loss: 24.7607 - accuracy: 0.4270
# Epoch 8/150
# 181/181 [==============================] - 0s 3ms/step - loss: 17.2194 - accuracy: 0.4424
# Epoch 9/150
# 181/181 [==============================] - 0s 2ms/step - loss: 12.4698 - accuracy: 0.4498
# Epoch 10/150
# ...
